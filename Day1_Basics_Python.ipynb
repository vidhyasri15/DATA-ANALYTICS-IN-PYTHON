# %%
month = 2
height = 1.7


type(month)
print(type(month))
# Out:
# <class 'int'>

# %%
 x = "Python programming"
type(x)
# Out:
# str

# %%
 x = Python programming
type(x)
# Out:
#   File "/tmp/ipykernel_9473/46570288.py", line 1
#     x = Python programming
#                ^
# SyntaxError: invalid syntax

# %%
y = 1
type(y)
#if(y)
# Out:
# int

# %%
mystr = "Python String"
mystr1 = "Second String"
print (mystr)
print (mystr1)
print(type(mystr))
print(type(mystr1))
# Out:
# Python String
# Second String
# <class 'str'>
# <class 'str'>

# %%
my_str = "PYTHON ROCKS"
#print (my_str)
#print(len(my_str))
#print(my_str[0])
print(my_str[11])
# Out:
# S

# %%
my_str = "PYTHON ROCKS"
print(my_str[0])
# Will not work
my_str[0]="M"
# Out:
# P
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9473/2479379879.py in <cell line: 0>()
#       2 print(my_str[0])
#       3 # Will not work
# ----> 4 my_str[0]="M"
#       5
#
# TypeError: 'str' object does not support item assignment

# %%
my_str = "PYTHON ROCKS"
print(my_str[1])
print("Y" in my_str)
print("A" in my_str)
print("ROCKS" in my_str)
# Out:
# Y
# True
# False
# True

# %%
my_str = "PYTHON ROCKS"
#print(len(my_str))
#print(my_str[0:8])
#print(my_str[-12:-1])
print(my_str[5:0])
print(my_str[-12:-6])
# Out:
# PYTHON

# %%
mytup1=(12,25.4,"PYTHON",212)
mytup2=(-21,224,87.6,"Hello",22)
print(mytup1)
print(len(mytup1))
print(type(mytup1))
print(mytup2)
print(len(mytup2))
type(mytup2)
# Out:
# (12, 25.4, 'PYTHON', 212)
# 4
# <class 'tuple'>
# (-21, 224, 87.6, 'Hello', 22)
# 5
# tuple

# %%
#To create empty or single element tuple
emptup = ()
#print(type(emptup))
#print(emptup)
onetup = (212,)
print(type(onetup))
print(onetup)
# Out:
# <class 'tuple'>
# (212,)

# %%
# Python3 code to demonstrate working of
# Concatenating tuples to nested tuples
# using + operator + ", " operator during initialization

# initialize tuples
test_tup1 = (3, 4),
test_tup2 = (5, 6),
# printing original tuples
print("The original tuple 1 : " + str(test_tup1))
print("The original tuple 2 : " + str(test_tup2))
# Concatenating tuples to nested tuples
# using + operator + ", " operator during initialization
res = test_tup1 + test_tup2
# printing result
print("Tuples after Concatenating : " + str(res))
# Out:
# The original tuple 1 : ((3, 4),)
# The original tuple 2 : ((5, 6),)
# Tuples after Concatenating : ((3, 4), (5, 6))

# %%
# Python3 code to demonstrate working of
# Repeating tuples N times
# using * operator

# initialize tuple
test_tup = (1, 3)

# printing original tuple
print("The original tuple : " + str(test_tup))# initialize N
N = 4

# Repeating tuples N times
# using * operator
res = ((test_tup,) * N)

# printing result
print("The duplicated tuple elements are : " + str(res))
# Out:
# The original tuple : (1, 3)
# The duplicated tuple elements are : ((1, 3), (1, 3), (1, 3), (1, 3))

# %%
fam = [1.73, 1.68, 1.71,1.89]
fam
# Out:
# [1.73, 1.68, 1.71, 1.89]

# %%
fam1 = ["liz",1.73,"mom",1.71,"dad",1.89]
fam1
type(fam1)
# Out:
# list

# %%
#List of lists
fam2 = [["liz", 1.73],
				["emma", 1.68],
				["mom", 1.71],
				["dad", 1.89]]
fam2

type(fam2)
# Out:
# list

# %%
fam = ["liz", 1.73,"mom", 1.71,"dad", 1.89]
fam
# Out:
# ['liz', 1.73, 'mom', 1.71, 'dad', 1.89]

# %%
#Out[2]: ['liz',1.73,'mom', 1.71, 'dad',1.89]
#Index : 	0 	   1 	  2 	  3 	   4 	   5
#		     -6	    -5   -4    -3	    -2	  -1
fam[3]
fam[-2]
fam[4]
# Out:
# 'dad'

# %%
fam = ["liz", 1.73,"mom", 1.71,"dad", 1.89]
fam
# Out:
# ['liz', 1.73, 'mom', 1.71, 'dad', 1.89]

# %%
#Out[2]: ['liz',1.73,'mom', 1.71, 'dad',1.89]
#Index :    0    1 	   2 	   3 	   4 	   5

fam[:5]
#fam[:4]
fam[3:]
# Out:
# [1.71, 'dad', 1.89]

# %%
fam = ["liz", 1.73,"mom", 1.71,"dad", 1.89]
#fam
#fam[5] = 1.7
#fam
#fam[0:2]
fam[0:2] = ["lisa", 1.74]
#fam

# %%
fam + ["me", 1.79]	   #adding elements
# Out:
# ['lisa', 1.74, 'mom', 1.71, 'dad', 1.89, 'me', 1.79]

# %%
del(fam[4])		 #removing elements
fam
# Out:
# ['lisa', 1.74, 'mom', 1.71, 1.89]

# %%
a = [1.73, 1.68, 1.71, 1.89]
a
max(a)
type(a)
# Out:
# list

# %%
round(1.68, 100)

#round(1.68)

help(round)   # opens up documentation
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
fam = ["liz", 1.73,"mom", 1.71,"dad", 1.89]
fam
fam.index("mom")  	# list method
# Out:
# 2

# %%
person = "liz"
#person
person.capitalize() 	# str method
# Out:
# 'Liz'

# %%
x = 175
bin(x)

x.bit_length()		# int method
# Out:
# 8

# %%
y = 1-3j
y
y.conjugate()		# complex method
# Out:
# (1+3j)

# %%
y=5
y <= 7 or y > 13
# Out:
# True

# %%
#y == 7 and y > 13
#not True
not False
# Out:
# True

# %%
z = 4
if z % 2 == 0 :
    print("z is even")
# Out:
# z is even

# %%
student_marks = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78,
    "David": 65,
    "Eve": 95
}

print(student_marks)
# Out:
# {'Alice': 85, 'Bob': 92, 'Charlie': 78, 'David': 65, 'Eve': 95}
